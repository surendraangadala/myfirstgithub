# %% [markdown]
# Suppose you have a list of countries that you have extracted from a large dataset.
# List of countries:
# "AF","AL","DZ","AS","AD","AO","AI","AQ","AG","AR","AM","AW","AU","AT","AZ","BS","BH","BD","BB
# ","BY","BE"
# How would you
# • Assign it to a variable in python (appropriate data type)?
# • Access the second value?
# • Check if the dataset is not empty?
# • Check if “AQ” exists in the dataset?

# %% [markdown]
# Assign it to a variable in python (appropriate data type)?
#
# we can use  list or tuple.

# %%
x=["AF","AL","DZ","AS","AD","AO","AI","AQ","AG","AR","AM","AW","AU","AT","AZ","BS","BH","BD","BB ","BY","BE"]

# %% [markdown]
#  Access the second value?
#
#     we have used the list and it can be indexed.

# %%
x[1]
# Out:
# 'AL'

# %% [markdown]
# Check if the dataset is not empty?
#
# we can check the dataset is empty or not by finding the length of the dataset, if length is zero than the data set is empty.

# %%
len(x)
# Out:
# 21

# %% [markdown]
#  Check if “AQ” exists in the dataset?

# %%
"AQ" in x
# Out:
# True

# %% [markdown]
# Import the COVID 19 dataset, total_cases.csv provided on the Moodle as Pandas
# DataFrame
# • Print the top five rows and the bottom five rows of the data
# • Print the columns corresponding to the United Kingdom, United States, and Sweden
# • Find the first quartile, second quartile, third quartile, and mean of COVID 19 cases
# for the United Kingdom and the United States. (HINT – You can use an inbuilt
# function in Pandas)

# %% [markdown]
# Import the COVID 19 dataset, total_cases.csv provided on the Moodle as Pandas DataFrame

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\st20172389\\Downloads\\total_cases.csv")

# %%
df
# Out:
#            date     World  Afghanistan  Albania  Algeria  Andorra   Angola  \
# 0    2019-12-31        27          NaN      NaN      NaN      NaN      NaN
# 1    2020-01-01        27          NaN      NaN      NaN      NaN      NaN
# 2    2020-01-02        27          NaN      NaN      NaN      NaN      NaN
# 3    2020-01-03        44          NaN      NaN      NaN      NaN      NaN
# 4    2020-01-04        44          NaN      NaN      NaN      NaN      NaN
# ..          ...       ...          ...      ...      ...      ...      ...
# 325  2020-11-20  57030619      44133.0  30623.0  71652.0   6066.0  13922.0
# 326  2020-11-21  57710848      44365.0  31459.0  72755.0   6142.0  14134.0
# 327  2020-11-22  58278092      44519.0  32196.0  73774.0   6207.0  14413.0
# 328  2020-11-23  58794150      44771.0  32761.0  74862.0   6256.0  14493.0
# 329  2020-11-24  59307493      45017.0  33556.0  75867.0   6304.0  14493.0
#
# ...

# %% [markdown]
#  Print the top five rows and the bottom five rows of the data

# %%
df.head()
# Out:
#          date  World  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 0  2019-12-31     27          NaN      NaN      NaN      NaN     NaN
# 1  2020-01-01     27          NaN      NaN      NaN      NaN     NaN
# 2  2020-01-02     27          NaN      NaN      NaN      NaN     NaN
# 3  2020-01-03     44          NaN      NaN      NaN      NaN     NaN
# 4  2020-01-04     44          NaN      NaN      NaN      NaN     NaN
#
#    Anguilla  Antigua and Barbuda  Argentina  ...  Uzbekistan  Vanuatu  \
# 0       NaN                  NaN        NaN  ...         NaN      NaN
# 1       NaN                  NaN        NaN  ...         NaN      NaN
# 2       NaN                  NaN        NaN  ...         NaN      NaN
# 3       NaN                  NaN        NaN  ...         NaN      NaN
# 4       NaN                  NaN        NaN  ...         NaN      NaN
#
#    Vatican  Venezuela  Vietnam  Wallis and Futuna  Western Sahara  Yemen  \
# ...

# %%
df.tail()
# Out:
#            date     World  Afghanistan  Albania  Algeria  Andorra   Angola  \
# 325  2020-11-20  57030619      44133.0  30623.0  71652.0   6066.0  13922.0
# 326  2020-11-21  57710848      44365.0  31459.0  72755.0   6142.0  14134.0
# 327  2020-11-22  58278092      44519.0  32196.0  73774.0   6207.0  14413.0
# 328  2020-11-23  58794150      44771.0  32761.0  74862.0   6256.0  14493.0
# 329  2020-11-24  59307493      45017.0  33556.0  75867.0   6304.0  14493.0
#
#      Anguilla  Antigua and Barbuda  Argentina  ...  Uzbekistan  Vanuatu  \
# 325       3.0                139.0  1349434.0  ...     71071.0      1.0
# 326       3.0                139.0  1359026.0  ...     71280.0      1.0
# 327       3.0                139.0  1366169.0  ...     71280.0      1.0
# 328       4.0                139.0  1370350.0  ...     71617.0      1.0
# 329       4.0                139.0  1374348.0  ...     71847.0      1.0
#
#      Vatican  Venezuela  Vietnam  Wallis and Futuna  Western Sahara   Yemen  \
# ...

# %% [markdown]
# Print the columns corresponding to the United Kingdom, United States, and Sweden

# %%
df.filter(['United Kingdom','Sweden','United States'])
# Out:
#      United Kingdom    Sweden  United States
# 0               NaN       NaN            NaN
# 1               NaN       NaN            NaN
# 2               NaN       NaN            NaN
# 3               NaN       NaN            NaN
# 4               NaN       NaN            NaN
# ..              ...       ...            ...
# 325       1453256.0  202052.0     11717827.0
# 326       1473508.0  208295.0     11913944.0
# 327       1493383.0       NaN     12089438.0
# 328       1512045.0       NaN     12246909.0
# 329       1527495.0       NaN     12420872.0
#
# [330 rows x 3 columns]

# %% [markdown]
# Find the first quartile, second quartile, third quartile, and mean of COVID 19 cases for the United Kingdom and the United States.

# %%
df.filter(['United Kingdom','United States']).describe()
# Out:
#        United Kingdom  United States
# count    2.980000e+02   3.090000e+02
# mean     3.371480e+05   3.571054e+06
# std      3.460354e+05   3.414074e+06
# min      2.000000e+00   1.000000e+00
# 25%      9.813350e+04   3.681960e+05
# 50%      2.827705e+05   2.312302e+06
# 75%      3.574082e+05   6.300671e+06
# max      1.527495e+06   1.242087e+07

# %%
df.filter(['United Kingdom','United States']).quantile(0.25)
# Out:
# United Kingdom     98133.5
# United States     368196.0
# Name: 0.25, dtype: float64

# %%
df.filter(['United Kingdom','United States']).quantile(0.50)
# Out:
# United Kingdom     282770.5
# United States     2312302.0
# Name: 0.5, dtype: float64

# %%
df.filter(['United Kingdom','United States']).quantile(0.75)
# Out:
# United Kingdom     357408.25
# United States     6300671.00
# Name: 0.75, dtype: float64
